# %%
import matplotlib as plt
import cmasher as cmr
from OoF.plot_data import generate_surface_mass_density_plot

# %%
simdir = '/Users/micahoeur/Dropbox/Research/Sarah/FIRE2_m12f_uv_background'
simnum = 600
species = 'star'
Rcyl = 8 #kpc
numvols = 16
zcut = 3.5 #kpc
agecut = 0

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({'font.size': 20})

plt.rcParams['figure.dpi'] = 150
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20

# %%
generate_surface_mass_density_plot(simdir, simnum, species, 'gas', Rcyl, numvols, zcut)
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  Users/micahoeur/Dropbox/Research/Sarah/FIRE2_m12f_uv_background/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Users/micahoeur/Dropbox/Research/Sarah/FIRE2_m12f_uv_background/output/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 81626920 particles
#     star      (id = 4): 15027738 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# ! cannot find MUSIC config file:  Users/micahoeur/Dropbox/Research/Sarah/FIRE2_m12f_uv_background/*/*.conf
# ! missing cosmological parameters, assuming cosmology from AGORA
# ...
